# %% [markdown]
# #### Connecting to clever cloud mysql

# %%
#!pip3 install mysql-connector-python

# %%
import mysql.connector 
from mysql.connector import Error
import pandas as pd

# %%
connection = mysql.connector.connect(
  host="bybz54wnxrpm7fu13bib-mysql.services.clever-cloud.com", # replace username, hostname, password and database name appropriately
  user="u5bzf3s3fpxkrg5t",
  password="X6CUkrBLPGlozcFG7N9u",
  database="bybz54wnxrpm7fu13bib"
)

cursor1 = connection.cursor()

# %%
df = pd.read_csv('titanic_train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df1=df.iloc[:,0:5]
df2.head()

# %%
df2=df.iloc[:,[0,6,7,8]]
df2.head()
# Out:
#    PassengerId  SibSp  Parch            Ticket
# 0            1      1      0         A/5 21171
# 1            2      1      0          PC 17599
# 2            3      0      0  STON/O2. 3101282
# 3            4      1      0            113803
# 4            5      0      0            373450

# %%
df3=df.iloc[:,[0,9,10,11]]
df2.head()

# %% [markdown]
# ###### Setp_1 : Creating a Table in DB name Table_1

# %%
cursor1.execute("CREATE TABLE Titanic_01 (PassengerId INT,Survived INT,Pclass INT,Name VARCHAR(255), Gender VARCHAR(255))")

# %%
cursor1.execute("CREATE TABLE Titanic_02 (PassengerId INT,SibSp INT,Parch INT,Ticket VARCHAR(255))")

# %% [markdown]
# ###### Setp2 :Inserting data to the table Table_1

# %%
for row in df1.iterrows():
    #print( row[1].values)
    sql="INSERT INTO Titanic_01 (PassengerId,Survived,Pclass,Name,Gender) VALUES (%s ,%s,%s ,%s,%s)"  #insert a single tuple
    val=tuple(row[1].values)
    cursor1.execute(sql,val)

# %%
for row in df2.iterrows():
    #print( row[1].values)
    sql="INSERT INTO Titanic_02 (PassengerId,SibSp,Parch,Ticket) VALUES (%s ,%s,%s ,%s)"  #insert a single tuple
    val=tuple(row[1].values)
    cursor1.execute(sql,val)

# %% [markdown]
# ###### LOADING THE DATA FROM THE TABLE

# %%
cursor1.execute('''SELECT * 
                 FROM Titanic_01
                 
                 ''')
result2=cursor1.fetchall()   #fetch all the tuple

for i in result2:
    print(i)
# Out:
# (1, 0, 3, 'Braund, Mr. Owen Harris', 'male')
# (2, 1, 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)', 'female')
# (3, 1, 3, 'Heikkinen, Miss. Laina', 'female')
# (4, 1, 1, 'Futrelle, Mrs. Jacques Heath (Lily May Peel)', 'female')
# (5, 0, 3, 'Allen, Mr. William Henry', 'male')
# (6, 0, 3, 'Moran, Mr. James', 'male')
# (7, 0, 1, 'McCarthy, Mr. Timothy J', 'male')
# (8, 0, 3, 'Palsson, Master. Gosta Leonard', 'male')
# (9, 1, 3, 'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)', 'female')
# (10, 1, 2, 'Nasser, Mrs. Nicholas (Adele Achem)', 'female')
# (11, 1, 3, 'Sandstrom, Miss. Marguerite Rut', 'female')
# (12, 1, 1, 'Bonnell, Miss. Elizabeth', 'female')
# (13, 0, 3, 'Saundercock, Mr. William Henry', 'male')
# (14, 0, 3, 'Andersson, Mr. Anders Johan', 'male')
# (15, 0, 3, 'Vestrom, Miss. Hulda Amanda Adolfina', 'female')
# (16, 1, 2, 'Hewlett, Mrs. (Mary D Kingcome) ', 'female')
# (17, 0, 3, 'Rice, Master. Eugene', 'male')
# ...

# %%
cursor1.execute('''SELECT * 
                 FROM Titanic_02
                 
                 ''')
result3=cursor1.fetchall()   #fetch all the tuple

for i in result3:
    print(i)
# Out:
# (1, 1, 0, 'A/5 21171')
# (2, 1, 0, 'PC 17599')
# (3, 0, 0, 'STON/O2. 3101282')
# (4, 1, 0, '113803')
# (5, 0, 0, '373450')
# (6, 0, 0, '330877')
# (7, 0, 0, '17463')
# (8, 3, 1, '349909')
# (9, 0, 2, '347742')
# (10, 1, 0, '237736')
# (11, 1, 1, 'PP 9549')
# (12, 0, 0, '113783')
# (13, 0, 0, 'A/5. 2151')
# (14, 1, 5, '347082')
# (15, 0, 0, '350406')
# (16, 0, 0, '248706')
# (17, 4, 1, '382652')
# (18, 0, 0, '244373')
# (19, 1, 0, '345763')
# (20, 0, 0, '2649')
# (21, 0, 0, '239865')
# (22, 0, 0, '248698')
# (23, 0, 0, '330923')
# (24, 0, 0, '113788')
# (25, 3, 1, '349909')
# (26, 1, 5, '347077')
# (27, 0, 0, '2631')
# (28, 3, 2, '19950')
# (29, 0, 0, '330959')
# (30, 0, 0, '349216')
# (31, 0, 0, 'PC 17601')
# (32, 1, 0, 'PC 17569')
# (33, 0, 0, '335677')
# (34, 0, 0, 'C.A. 24579')
# (35, 1, 0, 'PC 17604')
# (36, 1, 0, '113789')
# (37, 0, 0, '2677')
# (38, 0, 0, 'A./5. 2152')
# (39, 2, 0, '345764')
# (40, 1, 0, '2651')
# (41, 1, 0, '7546')
# (42, 1, 0, '11668')
# (43, 0, 0, '349253')
# ...
